# %% [markdown]
# ### This script contains the following points:
#
# #### 1. Create data to experiment on
# #### 2. Clean and Check Data

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
#Define path
path = r'C:\Users\Josh Abrams\Desktop\CF_CAPSTONE'

# %%
df_king = pd.read_csv(os.path.join(path, 'Data', 'Original Data', 'King Data Clean.csv'))

# %%
df_king
# Out:
#        Unnamed: 0          id        date  sale_price   bedrooms  bathrooms  \
# 0               0  7129300520  10/13/2014     221900.0         3       1.00
# 1               1  6414100192   12/9/2014     538000.0         3       2.25
# 2               2  5631500400   2/25/2015     180000.0         2       1.00
# 3               3  2487200875   12/9/2014     604000.0         4       3.00
# 4               4  1954400510   2/18/2015     510000.0         3       2.00
# ...           ...         ...         ...          ...       ...        ...
# 21608       21608   263000018   5/21/2014     360000.0         3       2.50
# 21609       21609  6600060120   2/23/2015     400000.0         4       2.50
# 21610       21610  1523300141   6/23/2014     402101.0         2       0.75
# 21611       21611   291310100   1/16/2015     400000.0         3       2.50
# 21612       21612  1523300157  10/15/2014     325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  ...  sqft_basement  \
# 0             1180      5650     1.0           0  ...              0
# 1             2570      7242     2.0           0  ...            400
# 2              770     10000     1.0           0  ...              0
# 3             1960      5000     1.0           0  ...            910
# 4             1680      8080     1.0           0  ...              0
# ...            ...       ...     ...         ...  ...            ...
# 21608         1530      1131     3.0           0  ...              0
# 21609         2310      5813     2.0           0  ...              0
# 21610         1020      1350     2.0           0  ...              0
# 21611         1600      2388     2.0           0  ...              0
# 21612         1020      1076     2.0           0  ...              0
#
#        yr_built  yr_renovated  zipcode       City  State      lat     long  \
# 0          1955             0    32642    Seattle     WA  47.5112 -122.257
# 1          1951          1991    32589    Seattle     WA  47.7210 -122.319
# 2          1933             0    32492    Kenmore     WA  47.7379 -122.233
# 3          1965             0    32600    Seattle     WA  47.5208 -122.393
# 4          1987             0    32538  Sammamish     WA  47.6168 -122.045
# ...         ...           ...      ...        ...    ...      ...      ...
# 21608      2009             0    32567    Seattle     WA  47.6993 -122.346
# 21609      2014             0    32610    Seattle     WA  47.5107 -122.362
# 21610      2009             0    32608    Seattle     WA  47.5944 -122.299
# 21611      2004             0    32491   Issaquah     WA  47.5345 -122.069
# 21612      2008             0    32608    Seattle     WA  47.5941 -122.299
#
#       sqft_living15 sqft_lot15
# 0              1340       5650
# 1              1690       7639
# 2              2720       8062
# 3              1360       5000
# 4              1800       7503
# ...             ...        ...
# 21608          1530       1509
# 21609          1830       7200
# 21610          1020       2007
# 21611          1410       1287
# 21612          1020       1357
#
# [21613 rows x 24 columns]

# %%
df_king.shape
# Out:
# (21613, 24)

# %%
df_king.describe()
# Out:
#         Unnamed: 0            id   sale_price       bedrooms     bathrooms  \
# count  21613.00000  2.161300e+04  2.161300e+04  21613.000000  21613.000000
# mean   10806.00000  4.580302e+09  5.400881e+05      3.370842      2.114757
# std     6239.28002  2.876566e+09  3.671272e+05      0.930062      0.770163
# min        0.00000  1.000102e+06  7.500000e+04      0.000000      0.000000
# 25%     5403.00000  2.123049e+09  3.219500e+05      3.000000      1.750000
# 50%    10806.00000  3.904930e+09  4.500000e+05      3.000000      2.250000
# 75%    16209.00000  7.308900e+09  6.450000e+05      4.000000      2.500000
# max    21612.00000  9.900000e+09  7.700000e+06     33.000000      8.000000
#
#         sqft_living      sqft_lot        floors    waterfront          view  \
# count  21613.000000  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean    2079.899736  1.510697e+04      1.494309      0.007542      0.234303
# std      918.440897  4.142051e+04      0.539989      0.086517      0.766318
# min      290.000000  5.200000e+02      1.000000      0.000000      0.000000
# 25%     1427.000000  5.040000e+03      1.000000      0.000000      0.000000
# 50%     1910.000000  7.618000e+03      1.500000      0.000000      0.000000
# 75%     2550.000000  1.068800e+04      2.000000      0.000000      0.000000
# max    13540.000000  1.651359e+06      3.500000      1.000000      4.000000
#
#        ...         grade    sqft_above  sqft_basement      yr_built  \
# count  ...  21613.000000  21613.000000   21613.000000  21613.000000
# mean   ...      7.656873   1788.390691     291.509045   1971.005136
# std    ...      1.175459    828.090978     442.575043     29.373411
# min    ...      1.000000    290.000000       0.000000   1900.000000
# 25%    ...      7.000000   1190.000000       0.000000   1951.000000
# 50%    ...      7.000000   1560.000000       0.000000   1975.000000
# 75%    ...      8.000000   2210.000000     560.000000   1997.000000
# max    ...     13.000000   9410.000000    4820.000000   2015.000000
#
#        yr_renovated       zipcode           lat          long  sqft_living15  \
# count  21613.000000  21613.000000  21613.000000  21613.000000   21613.000000
# mean      84.402258  32541.939805     47.560053   -122.213896    1986.552492
# std      401.679240     53.505026      0.138564      0.140828     685.391304
# min        0.000000  32465.000000     47.155900   -122.519000     399.000000
# 25%        0.000000  32497.000000     47.471000   -122.328000    1490.000000
# 50%        0.000000  32529.000000     47.571800   -122.230000    1840.000000
# 75%        0.000000  32582.000000     47.678000   -122.125000    2360.000000
# max     2015.000000  32663.000000     47.777600   -121.315000    6210.000000
#
#           sqft_lot15
# count   21613.000000
# mean    12768.455652
# std     27304.179631
# min       651.000000
# 25%      5100.000000
# 50%      7620.000000
# 75%     10083.000000
# max    871200.000000
#
# [8 rows x 21 columns]

# %%
df_king.dtypes
# Out:
# Unnamed: 0         int64
# id                 int64
# date              object
# sale_price       float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# City              object
# State             object
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
## Reducing data types to save RAM before merge
df_king['bedrooms'] = df_king['bedrooms'].astype('int8')
df_king['bathrooms'] = df_king['bathrooms'].astype('float16')
df_king['floors'] = df_king['floors'].astype('float16')
df_king['waterfront'] = df_king['waterfront'].astype('object')
df_king['view'] = df_king['view'].astype('object')
df_king['condition'] = df_king['condition'].astype('object')
df_king['grade'] = df_king['grade'].astype('object')
df_king['zipcode'] = df_king['zipcode'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2504\72013519.py in <module>
#       1 ## Reducing data types to save RAM before merge
# ----> 2 df_king['bedrooms'] = df_king['bedrooms'].astype('int8')
#       3 df_king['bathrooms'] = df_king['bathrooms'].astype('float16')
#       4 df_king['floors'] = df_king['floors'].astype('float16')
#       5 df_king['waterfront'] = df_king['waterfront'].astype('object')
#
# NameError: name 'df_king' is not defined

# %%
df_king.dtypes
# Out:
# Unnamed: 0         int64
# id                 int64
# date              object
# sale_price       float64
# bedrooms            int8
# bathrooms        float16
# sqft_living        int64
# sqft_lot           int64
# floors           float16
# waterfront        object
# view              object
# condition         object
# grade             object
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int16
# City              object
# State             object
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
df_king.head()
# Out:
#    Unnamed: 0          id        date  sale_price   bedrooms  bathrooms  \
# 0           0  7129300520  10/13/2014     221900.0         3       1.00
# 1           1  6414100192   12/9/2014     538000.0         3       2.25
# 2           2  5631500400   2/25/2015     180000.0         2       1.00
# 3           3  2487200875   12/9/2014     604000.0         4       3.00
# 4           4  1954400510   2/18/2015     510000.0         3       2.00
#
#    sqft_living  sqft_lot  floors waterfront  ... sqft_basement yr_built  \
# 0         1180      5650     1.0          0  ...             0     1955
# 1         2570      7242     2.0          0  ...           400     1951
# 2          770     10000     1.0          0  ...             0     1933
# 3         1960      5000     1.0          0  ...           910     1965
# 4         1680      8080     1.0          0  ...             0     1987
#
#   yr_renovated  zipcode       City  State      lat     long sqft_living15  \
# 0            0    32642    Seattle     WA  47.5112 -122.257          1340
# 1         1991    32589    Seattle     WA  47.7210 -122.319          1690
# 2            0    32492    Kenmore     WA  47.7379 -122.233          2720
# 3            0    32600    Seattle     WA  47.5208 -122.393          1360
# 4            0    32538  Sammamish     WA  47.6168 -122.045          1800
#
#   sqft_lot15
# 0       5650
# 1       7639
# 2       8062
# 3       5000
# 4       7503
#
# [5 rows x 24 columns]

# %%
df_king.tail()
# Out:
#        Unnamed: 0          id        date  sale_price   bedrooms  bathrooms  \
# 21608       21608   263000018   5/21/2014     360000.0         3       2.50
# 21609       21609  6600060120   2/23/2015     400000.0         4       2.50
# 21610       21610  1523300141   6/23/2014     402101.0         2       0.75
# 21611       21611   291310100   1/16/2015     400000.0         3       2.50
# 21612       21612  1523300157  10/15/2014     325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors waterfront  ... sqft_basement yr_built  \
# 21608         1530      1131     3.0          0  ...             0     2009
# 21609         2310      5813     2.0          0  ...             0     2014
# 21610         1020      1350     2.0          0  ...             0     2009
# 21611         1600      2388     2.0          0  ...             0     2004
# 21612         1020      1076     2.0          0  ...             0     2008
#
#       yr_renovated  zipcode      City  State      lat     long sqft_living15  \
# 21608            0    32567   Seattle     WA  47.6993 -122.346          1530
# 21609            0    32610   Seattle     WA  47.5107 -122.362          1830
# 21610            0    32608   Seattle     WA  47.5944 -122.299          1020
# 21611            0    32491  Issaquah     WA  47.5345 -122.069          1410
# 21612            0    32608   Seattle     WA  47.5941 -122.299          1020
#
#       sqft_lot15
# 21608       1509
# 21609       7200
# 21610       2007
# 21611       1287
# 21612       1357
#
# [5 rows x 24 columns]

# %%
df_king.isnull().sum()
# Out:
# Unnamed: 0       0
# id               0
# date             0
# sale_price       0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# City             0
# State            0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df_king.describe()
# Out:
#         Unnamed: 0            id   sale_price       bedrooms     bathrooms  \
# count  21613.00000  2.161300e+04  2.161300e+04  21613.000000  21613.000000
# mean   10806.00000  4.580302e+09  5.400881e+05      3.370842      2.115234
# std     6239.28002  2.876566e+09  3.671272e+05      0.930062      0.770020
# min        0.00000  1.000102e+06  7.500000e+04      0.000000      0.000000
# 25%     5403.00000  2.123049e+09  3.219500e+05      3.000000      1.750000
# 50%    10806.00000  3.904930e+09  4.500000e+05      3.000000      2.250000
# 75%    16209.00000  7.308900e+09  6.450000e+05      4.000000      2.500000
# max    21612.00000  9.900000e+09  7.700000e+06     33.000000      8.000000
#
#         sqft_living      sqft_lot        floors    sqft_above  sqft_basement  \
# count  21613.000000  2.161300e+04  21613.000000  21613.000000   21613.000000
# mean    2079.899736  1.510697e+04      1.495117   1788.390691     291.509045
# std      918.440897  4.142051e+04      0.540039    828.090978     442.575043
# min      290.000000  5.200000e+02      1.000000    290.000000       0.000000
# 25%     1427.000000  5.040000e+03      1.000000   1190.000000       0.000000
# 50%     1910.000000  7.618000e+03      1.500000   1560.000000       0.000000
# 75%     2550.000000  1.068800e+04      2.000000   2210.000000     560.000000
# max    13540.000000  1.651359e+06      3.500000   9410.000000    4820.000000
#
#            yr_built  yr_renovated       zipcode           lat          long  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean    1971.005136     84.402258  32541.939805     47.560053   -122.213896
# std       29.373411    401.679240     53.505026      0.138564      0.140828
# min     1900.000000      0.000000  32465.000000     47.155900   -122.519000
# 25%     1951.000000      0.000000  32497.000000     47.471000   -122.328000
# 50%     1975.000000      0.000000  32529.000000     47.571800   -122.230000
# 75%     1997.000000      0.000000  32582.000000     47.678000   -122.125000
# max     2015.000000   2015.000000  32663.000000     47.777600   -121.315000
#
#        sqft_living15     sqft_lot15
# count   21613.000000   21613.000000
# mean     1986.552492   12768.455652
# std       685.391304   27304.179631
# min       399.000000     651.000000
# 25%      1490.000000    5100.000000
# 50%      1840.000000    7620.000000
# 75%      2360.000000   10083.000000
# max      6210.000000  871200.000000

# %%
df_king.to_csv(os.path.join(path, 'Data', 'Prepared Data', 'King Data Clean.csv'))
